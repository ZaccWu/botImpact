# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

# %% [raw]
# Ch3# GCN Prediction

# %%
# t1 pos
plt.figure(figsize=(5,5))

label = ['t1_pos', 't1_neg', 't2_pos', 't2_neg', 't3_pos', 't3_neg']
aucH = [0.9261, 0.8570, 0.8318, 0.9225, 0.9023, 0.8709]
aucB = [0.8777, 0.8400, 0.7875, 0.8625, 0.8763, 0.8361]

plt.errorbar(label, aucH, label='Human AUC', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.errorbar(label, aucB, label='Bot AUC', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='deepskyblue', zorder=2)
plt.ylim(0.73, 0.94)
plt.tick_params(labelsize=16)
plt.xticks([])

plt.legend(fontsize=18)
plt.savefig('gcn_auc.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# t1 pos
plt.figure(figsize=(5,5))

label = ['t1_pos', 't2_pos', 't3_pos', 't1_neg', 't2_neg', 't3_neg']
apH = [0.9355, 0.8814, 0.8630, 0.9356, 0.9191, 0.8905]
apB = [0.9019, 0.8726, 0.8470, 0.8945, 0.9082, 0.8631]

plt.errorbar(label, apH, label='Human AP', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.errorbar(label, apB, label='Bot AP', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='deepskyblue', zorder=2)


plt.ylim(0.8, 0.95)
plt.tick_params(labelsize=16)
plt.xticks([])

plt.legend(fontsize=18)
plt.savefig('gcn_ap.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %% [raw]
# Ch5# Simulation

# %%
# homophily influence: bias, random
plt.figure(figsize=(5,5))

label = ['0','0.4','0.8','1.2','1.6','2','2.4']
biasNaive = [0.0109, 0.1875, 0.4016, 0.6582, 0.8225, 0.9677, 1.1422]
biasAdvG = [0.0315, 0.0781, 0.1001, 0.1312, 0.1457, 0.1858, 0.2453]

plt.errorbar(label, biasNaive, label='Naive', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='blue', zorder=2)
plt.errorbar(label, biasAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.ylim(0, 2)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_bZbias_random.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# homophily influence: bias, highdu
plt.figure(figsize=(5,5))

label = ['0','0.4','0.8','1.2','1.6','2','2.4']
biasNaive = [0.0026, 0.2357, 0.4175, 0.6207, 0.8747, 1.0711, 1.2961]
biasAdvG = [0.0377, 0.0799, 0.0980, 0.1199, 0.1450, 0.2377, 0.2740]

plt.errorbar(label, biasNaive, label='Naive', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='blue', zorder=2)
plt.errorbar(label, biasAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.ylim(0, 2)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_bZbias_highdu.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# homophily influence: ePEHE, random
plt.figure(figsize=(5,5))

label = ['0','0.4','0.8','1.2','1.6','2','2.4']
epeheAdvG = [0.0557, 0.0925, 0.1087, 0.1447, 0.1518, 0.2015, 0.2574]
epeheGial = [0.0735, 0.1331, 0.1650, 0.1735, 0.2453, 0.3351, 0.4015]
epeheIgnite = [0.0573, 0.1726, 0.2296, 0.2741, 0.3793, 0.4420, 0.4989]

plt.errorbar(label, epeheAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.errorbar(label, epeheGial, label='Gial', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='gold', zorder=2)
plt.errorbar(label, epeheIgnite, label='Ignite', alpha=0.7, linewidth = 2, marker = 'D', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='deepskyblue', zorder=2)
plt.ylim(0, 1)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_bZpehe_random.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# homophily influence: ePEHE, highdu
plt.figure(figsize=(5,5))

label = ['0','0.4','0.8','1.2','1.6','2','2.4']
epeheAdvG = [0.0568, 0.0902, 0.0997, 0.1206, 0.1468, 0.2405, 0.3022]
epeheGial = [0.0613, 0.1513, 0.1713, 0.2044, 0.2641, 0.3813, 0.4737]
epeheIgnite = [0.0576, 0.1477, 0.1766, 0.2894, 0.4214, 0.4847, 0.5201]

plt.errorbar(label, epeheAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.errorbar(label, epeheGial, label='Gial', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='gold', zorder=2)
plt.errorbar(label, epeheIgnite, label='Ignite', alpha=0.7, linewidth = 2, marker = 'D', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='deepskyblue', zorder=2)
plt.ylim(0, 1)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_bZpehe_highdu.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# homophily link: bias, random
plt.figure(figsize=(5,5))

label = ['0.56','0.65','0.71','0.80','0.87','0.95']
biasNaive = [0.1070, 0.2521, 0.3842, 0.4738, 0.6267, 0.8275]
biasAdvG = [0.0482, 0.0628, 0.0764, 0.0805, 0.1144, 0.1753]

plt.errorbar(label, biasNaive, label='Naive', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='blue', zorder=2)
plt.errorbar(label, biasAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.ylim(0, 1.5)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_AveNeiZbias_random.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# homophily link: bias, highdu
plt.figure(figsize=(5,5))

label = ['0.56','0.65','0.71','0.80','0.87','0.95']
biasNaive = [0.0905, 0.2333, 0.3715, 0.4877, 0.6659, 0.8078]
biasAdvG = [0.0575, 0.0626,	0.0729, 0.0887, 0.1210, 0.1542]

plt.errorbar(label, biasNaive, label='Naive', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='blue', zorder=2)
plt.errorbar(label, biasAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.ylim(0, 1.5)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_AveNeiZbias_highdu.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# homophily link: ePEHE, random
plt.figure(figsize=(5,5))

label = ['0.56','0.65','0.71','0.80','0.87','0.95']
epeheAdvG = [0.0556, 0.0741, 0.0806, 0.0836, 0.1198, 0.1811]
epeheGial = [0.0778, 0.1449, 0.1570, 0.1744, 0.2104, 0.2781]
epeheIgnite = [0.0810, 0.1817, 0.2005, 0.2247, 0.2935, 0.4132]

plt.errorbar(label, epeheAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.errorbar(label, epeheGial, label='Gial', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='gold', zorder=2)
plt.errorbar(label, epeheIgnite, label='Ignite', alpha=0.7, linewidth = 2, marker = 'D', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='deepskyblue', zorder=2)
plt.ylim(0, 0.8)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_AveNeiZepehe_random.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
# homophily link: ePEHE, highdu
plt.figure(figsize=(5,5))

label = ['0.56','0.65','0.71','0.80','0.87','0.95']
epeheAdvG = [0.0669, 0.0733, 0.0786, 0.0899, 0.1228, 0.1555]
epeheGial = [0.0709, 0.1509, 0.1559, 0.1650, 0.2032, 0.2529]
epeheIgnite = [0.0771, 0.1529, 0.1557, 0.1785, 0.3145, 0.3882]

plt.errorbar(label, epeheAdvG, label='AdvG', alpha=0.7, linewidth = 2, marker = 's', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='orangered', zorder=2)
plt.errorbar(label, epeheGial, label='Gial', alpha=0.7, linewidth = 2, marker = 'o', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='gold', zorder=2)
plt.errorbar(label, epeheIgnite, label='Ignite', alpha=0.7, linewidth = 2, marker = 'D', elinewidth=0.5, capsize=1, capthick=2, ms=11, mec='black',
             color='deepskyblue', zorder=2)
plt.ylim(0, 0.8)
plt.tick_params(labelsize=16)
plt.legend(fontsize=18)
plt.savefig('sen_AveNeiZepehe_highdu.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %% [raw]
# Ch6# Validity Check

# %%
from collections import OrderedDict
fig = plt.figure(figsize=(7.5,4))


inf_change = [0.0452, 0.0365, 0.0426, 0.0519, 0.0270, 0.0458]
auc_diff = [0.0484, 0.0170, 0.0443, 0.0600, 0.0260, 0.0348]


plt.bar(0.1, height=inf_change[0], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(0.2, height=auc_diff[0], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AUC Diff')

plt.bar(0.4, height=inf_change[1], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(0.5, height=auc_diff[1], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AUC Diff')

plt.bar(0.7, height=inf_change[2], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(0.8, height=auc_diff[2], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AUC Diff')

plt.bar(1.0, height=inf_change[3], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(1.1, height=auc_diff[3], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AUC Diff')

plt.bar(1.3, height=inf_change[4], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(1.4, height=auc_diff[4], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AUC Diff')

plt.bar(1.6, height=inf_change[5], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(1.7, height=auc_diff[5], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AUC Diff')

plt.ylim(0.,0.075)
plt.tick_params(labelsize=16)

plt.xticks([])

handles, labels = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), fontsize=15, ncol=2)
plt.savefig('diff_gcn_auc.jpg', bbox_inches = 'tight', dpi=500)
plt.show()

# %%
from collections import OrderedDict
fig = plt.figure(figsize=(7.5,4))


inf_change = [0.0452, 0.0365, 0.0426, 0.0519, 0.0270, 0.0458]
ap_diff = [0.0336, 0.0088, 0.0160, 0.0411, 0.0109, 0.0274]


plt.bar(0.1, height=inf_change[0], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(0.2, height=ap_diff[0], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AP Diff')

plt.bar(0.4, height=inf_change[1], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(0.5, height=ap_diff[1], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AP Diff')

plt.bar(0.7, height=inf_change[2], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(0.8, height=ap_diff[2], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AP Diff')

plt.bar(1.0, height=inf_change[3], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(1.1, height=ap_diff[3], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AP Diff')

plt.bar(1.3, height=inf_change[4], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(1.4, height=ap_diff[4], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AP Diff')

plt.bar(1.6, height=inf_change[5], width=0.07, color='snow', hatch='//', edgecolor='black', linewidth= 0.5, label='Result Diff')
plt.bar(1.7, height=ap_diff[5], width=0.07, color='orangered', edgecolor='black', linewidth= 0.5, label='AP Diff')

plt.ylim(0.,0.07)
plt.tick_params(labelsize=16)

plt.xticks([])

handles, labels = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), fontsize=15, ncol=2)
plt.savefig('diff_gcn_ap.jpg', bbox_inches = 'tight', dpi=500)
plt.show()
